# %% [markdown]
# * Load nodes

# %%
nodes_dir = '../data/Kcities/'

# %%
import numpy as np
nodes = np.loadtxt(nodes_dir+'AF_1_city_1_COORDS.txt',skiprows=1)

# %%
x1 = nodes[:,1]
x2 = nodes[:,2]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(x1,x2,s=0.5,alpha=0.5)
# plt.xlim([6155000,6165000])

# %% [markdown]
# * Load edges

# %%
edges_dir = '../data/edges/'

# %%
edges = np.loadtxt(edges_dir+'AF_1_city_1_NCOL.txt',skiprows=1)

# %%
nodes[0]
# Out:
# array([      0.        , 7675247.70187773, 4109306.05428234])

# %%
edges[0]
# Out:
# array([ 1.        ,  2.        , 32.70187115])

# %% [markdown]
# * Visualise network using matplotlib

# %%
vertices = dict(zip(nodes[:,0],nodes[:,1:]))

# %%
import matplotlib.pyplot as plt

# %%
for edge in edges:
    x,y = zip(vertices[edge[0]],vertices[edge[1]])
    plt.plot(x,y,'k')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-dc36b02402bd> in <module>()
#       1 for edge in edges:
#       2     x,y = zip(vertices[edge[0]],vertices[edge[1]])
# ----> 3     plt.plot(x,y,'k')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %% [markdown]
# * Visualise network using matplotlib LineCollection

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lines = [[vertices[edge[0]],vertices[edge[1]]] for edge in edges]

# %%
weights = [0.1*np.log(edge[2]) for edge in edges]
# Out:
# /Users/kirakempinska/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
lc = mc.LineCollection(lines, linewidths=weights, colors='k')
fig, ax = pl.subplots()
ax.add_collection(lc)
ax.autoscale()
plt.axis("off")
# Out:
# (7671596.185939485, 7721891.893358684, 4072315.843448459, 4122760.409344821)

# %%
ax.get_xlim()
# Out:
# (7671596.185939485, 7721891.893358684)

# %%
ax.get_ylim()
# Out:
# (4072315.843448459, 4122760.409344821)

# %%
yrange = 4122760.409344821 - 4072315.843448459

# %%
yrange
# Out:
# 50444.5658963616

# %%
xrange = 7721891.893358684 - 7671596.185939485

# %%
xrange
# Out:
# 50295.70741919894

# %% [markdown]
# * Get x,y ranges for all cities

# %%
import os
import numpy as np

# %%
nodes_dir = '../data/Kcities/'
names_coords = os.listdir('../data/Kcities/')
edges_dir = '../data/edges/'

# %%
names = []
for name in names_coords:
    names.append(name.rstrip('_COORDS.txt'))

# %%
names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c8beb69a2cd4> in <module>()
# ----> 1 names
#
# NameError: name 'names' is not defined

# %%
import os

datadir = '../data/Kcities/'
filenames = os.listdir(datadir)

filenames_coords = set()
filenames_edges = set()
for fn in filenames:
    if 'boundary' in fn or 'HI.txt' in fn:
        pass
    else:
        if 'COORDS' in fn:
            filenames_coords.add(fn)
        elif 'NCOL' in fn:
            filenames_edges.add(fn)
        else:
            print(fn)
# Out:
# worldColorScale.png
# names.txt
# Kcities.zip
# worldCities_above5e5.txt
# worldCities.png
# getFiles.py
# mxTest.qgs~
# mxTest.qgs
# KcitiesEdges.zip

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fn.rstrip('_COORDS.txt')
# Out:
# 'IR_1_city_11_HI'

# %%
fn = 'JP_3_city_2_COORDS.txt'

# %%
try:
    name = fn.rstrip('_COORDS.txt')
    nodes = np.loadtxt(datadir+fn,skiprows=1)
    edges = np.loadtxt(datadir+name+'_NCOL.txt',skiprows=1)
    nodes_dict = dict(zip(nodes[:,0],nodes[:,1:]))
    lines = [[nodes_dict[edge[0]],nodes_dict[edge[1]]] for edge in edges]
    weights = [0.1*np.log(edge[2]) for edge in edges]

    lc = mc.LineCollection(lines, linewidths=weights, colors='k')
    fig, ax = pl.subplots()
    ax.add_collection(lc)
    ax.autoscale()
    plt.axis("off")
    plt.show()
#     plt.savefig('../data/figures/%s.png' % (name))
#     plt.close()

    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    xranges.append(xlim[1]-xlim[0])
    yranges.append(ylim[1]-ylim[0])
except Exception as e:
    print("Filename:",fn)
    print(e)
# Out:
# /Users/kirakempinska/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
import matplotlib.cm as cm

# %%
# fn = 'IN_1_city_66_COORDS.txt'
fn = 'JP_3_city_2_COORDS.txt'

try:
    name = fn.rstrip('_COORDS.txt')
    nodes = np.loadtxt(datadir+fn,skiprows=1)
    edges = np.loadtxt(datadir+name+'_NCOL.txt',skiprows=1)
    nodes_dict = dict(zip(nodes[:,0],nodes[:,1:]))
    lines = [[nodes_dict[edge[0]],nodes_dict[edge[1]]] for edge in edges]
    weights = [0.1*np.log(edge[2]) for edge in edges]

    lc = mc.LineCollection(lines, linewidths=weights, colors='k')
    fig, ax = pl.subplots()
    ax.add_collection(lc)
    ax.autoscale()
    plt.axis("off")
#     plt.show()
#     plt.savefig('../data/%s.png' % (name))
#     plt.close()

    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    print(xlim)
    print(ylim)
    print(xlim[1]-xlim[0])
    print(ylim[1]-ylim[0])
    
    centroid_x = np.sum(xlim)/2
    centroid_y = np.sum(ylim)/2
    
    plt.xlim(centroid_x-10000,centroid_x+10000)
    plt.ylim(centroid_y-10000,centroid_y+10000)
    fig.set_size_inches(3.5, 3.5)
    plt.savefig('../data/%s.png' % (name), cmap=cm.gray)

    xranges.append(xlim[1]-xlim[0])
    yranges.append(ylim[1]-ylim[0])
except Exception as e:
    print("Filename:",fn)
    print(e)
# Out:
# /Users/kirakempinska/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.
# (14509046.342357801, 14614582.086865395)
# (3966332.913551519, 4043718.675367541)
# 105535.74450759403
# 77385.76181602199

# %%
centroid_x = np.sum(xlim)/2
centroid_y = np.sum(ylim)/2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig.show()
# Out:
# /Users/kirakempinska/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plt.xlim(centroid_x-50000,centroid_x+50000)
plt.ylim(centroid_y-50000,centroid_y+50000)
# plt.show()
# Out:
# (3955025.79445953, 4055025.79445953)

# %%
centroid_x
# Out:
# 14561814.214611597

# %%
xranges = []
yranges = []

for fn in filenames_coords:
    try:
        name = fn.rstrip('_COORDS.txt')
        nodes = np.loadtxt(datadir+fn,skiprows=1)
        edges = np.loadtxt(datadir+name+'_NCOL.txt',skiprows=1)
        nodes_dict = dict(zip(nodes[:,0],nodes[:,1:]))
        lines = [[nodes_dict[edge[0]],nodes_dict[edge[1]]] for edge in edges]
        weights = [0.1*np.log(edge[2]) for edge in edges]

        lc = mc.LineCollection(lines, linewidths=weights, colors='k')
        fig, ax = pl.subplots()
        ax.add_collection(lc)
        ax.autoscale()
        plt.axis("off")
        plt.savefig('../data/figures/%s.png' % (name))
        plt.close()

        xlim = ax.get_xlim()
        ylim = ax.get_ylim()

        xranges.append(xlim[1]-xlim[0])
        yranges.append(ylim[1]-ylim[0])
    except Exception as e:
        print("Filename:",fn)
        print(e)
# Out:
# /Users/kirakempinska/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f3139114a9e9> in <module>()
#       6         name = fn.rstrip('_COORDS.txt')
#       7         nodes = np.loadtxt(datadir+fn,skiprows=1)
# ----> 8         edges = np.loadtxt(datadir+name+'_NCOL.txt',skiprows=1)
#       9         nodes_dict = dict(zip(nodes[:,0],nodes[:,1:]))
#      10         lines = [[nodes_dict[edge[0]],nodes_dict[edge[1]]] for edge in edges]
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     915             fname = str(fname)
#     916         if _is_string_like(fname):
# ...

# %%
nodes_dir = '../data/Kcities/'
edges_dir = '../data/edges/'

nodes = np.loadtxt(nodes_dir+'AF_1_city_1_COORDS.txt',skiprows=1)
edges = np.loadtxt(edges_dir+'AF_1_city_1_NCOL.txt',skiprows=1)
nodes_dict = dict(zip(nodes[:,0],nodes[:,1:]))

lines = [[nodes_dict[edge[0]],nodes_dict[edge[1]]] for edge in edges]
weights = [0.1*np.log(edge[2]) for edge in edges]

lc = mc.LineCollection(lines, linewidths=weights, colors='k')
fig, ax = pl.subplots()
ax.add_collection(lc)
ax.autoscale()
plt.axis("off")
plt.savefig('../data/figures/AF_1_city_1.png')
plt.close()
# Out:
# /Users/kirakempinska/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
names
# Out:
# ['EG_1_city_1',
#  'UZ_1_city_1',
#  'PE_1_city_1',
#  'KP_1_city_1',
#  'AR_1_city_1',
#  'UK_1_city_6',
#  'AU_1_city_1',
#  'FR_1_city_5',
#  'AE_1_city_1',
#  'AF_1_city_1',
#  'UA_1_city_2',
#  'HU_1_city_1',
#  'SA_1_city_1',
#  'ID_2_city_1',
#  'RU_1_city_13',
#  'KR_1_city_8',
#  'TR_1_city_2',
#  'HK_1_city_1',
#  'GH_1_city_1',
#  'ES_1_city_2',
#  'MX_1_city_1',
#  'PL_1_city_2']

# %%
xranges
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-88728115ec8f> in <module>()
# ----> 1 xranges
#
# NameError: name 'xranges' is not defined

# %%
min(xranges)
# Out:
# 27006.45466640033

# %%
max(xranges)
# Out:
# 211542.3435672028

# %%
names
# Out:
# ['EG_1_city_1',
#  'UZ_1_city_1',
#  'PE_1_city_1',
#  'KP_1_city_1',
#  'AR_1_city_1',
#  'UK_1_city_6',
#  'AU_1_city_1',
#  'FR_1_city_5',
#  'AE_1_city_1',
#  'AF_1_city_1',
#  'UA_1_city_2',
#  'HU_1_city_1',
#  'SA_1_city_1',
#  'ID_2_city_1',
#  'RU_1_city_13',
#  'KR_1_city_8',
#  'TR_1_city_2',
#  'HK_1_city_1',
#  'GH_1_city_1',
#  'ES_1_city_2',
#  'MX_1_city_1',
#  'PL_1_city_2']

# %%
names_coords
# Out:
# ['EG_1_city_1_COORDS.txt',
#  'UZ_1_city_1_COORDS.txt',
#  'PE_1_city_1_COORDS.txt',
#  'KP_1_city_1_COORDS.txt',
#  'AR_1_city_1_COORDS.txt',
#  'UK_1_city_6_COORDS.txt',
#  'AU_1_city_1_COORDS.txt',
#  'FR_1_city_5_COORDS.txt',
#  'AE_1_city_1_COORDS.txt',
#  'AF_1_city_1_COORDS.txt',
#  'UA_1_city_2_COORDS.txt',
#  'HU_1_city_1_COORDS.txt',
#  'SA_1_city_1_COORDS.txt',
#  'ID_2_city_1_COORDS.txt',
#  'RU_1_city_13_COORDS.txt',
#  'KR_1_city_8_COORDS.txt',
#  'TR_1_city_2_COORDS.txt',
#  'HK_1_city_1_COORDS.txt',
#  'GH_1_city_1_COORDS.txt',
#  'ES_1_city_2_COORDS.txt',
#  'MX_1_city_1_COORDS.txt',
#  'PL_1_city_2_COORDS.txt']

# %%
lines[0]
# Out:
# [array([7675353.2550189 , 4109238.57271199]),
#  array([7675374.16081928, 4109204.791509  ])]

# %%
edges
# Out:
# array([[1.00000000e+00, 2.00000000e+00, 3.27018711e+01],
#        [2.00000000e+00, 3.00000000e+00, 3.08952310e+02],
#        [3.00000000e+00, 1.22000000e+02, 1.69069209e+01],
#        ...,
#        [5.38670000e+04, 5.26040000e+04, 5.68135563e+02],
#        [5.37730000e+04, 5.38020000e+04, 2.66336483e+02],
#        [5.38020000e+04, 5.37720000e+04, 1.29043373e+02]])

# %%
vertices
# Out:
# {0.0: array([7675247.70187773, 4109306.05428234]),
#  1.0: array([7675353.2550189 , 4109238.57271199]),
#  2.0: array([7675374.16081928, 4109204.791509  ]),
#  3.0: array([7675650.06617721, 4108950.3538867 ]),
#  4.0: array([7676429.07997378, 4107897.24761681]),
#  5.0: array([7676430.0373214 , 4107904.37355796]),
#  6.0: array([7676454.60553302, 4108073.3421697 ]),
#  7.0: array([7676463.34411304, 4107928.27997418]),
#  8.0: array([7676582.87898226, 4107835.73754608]),
#  9.0: array([7676599.73275316, 4107802.21747122]),
#  10.0: array([7676608.64944437, 4107723.33278443]),
#  11.0: array([7676617.10972568, 4107625.45109846]),
#  12.0: array([7677098.26596073, 4106944.54862391]),
#  13.0: array([7677319.65816402, 4106793.97116369]),
#  14.0: array([7678144.84728537, 4106484.15596886]),
#  15.0: array([7678980.52270276, 4105803.72821219]),
#  16.0: array([7678983.79549579, 4105798.84778675]),
#  17.0: array([7679344.17008333, 4105174.73859786]),
# ...

# %% [markdown]
# * Visualise network

# %%
import networkx as nx

# %%
G=nx.Graph()

# %%
edge_list = list(map(tuple, edges[:,0:2].astype(int)))

# %%
node_positions =

# %%
G.add_edges_from(edge_list)

# %%
nx.draw_networkx(G, pos=nodes)

# %%
nx.draw(G)
# Out:
# /Users/kirakempinska/anaconda3/lib/python3.6/site-packages/networkx/drawing/layout.py:499: RuntimeWarning: invalid value encountered in sqrt
#   distance = np.sqrt((delta**2).sum(axis=0))

# %%
data
# Out:
# array([[1.00000000e+00, 2.00000000e+00, 3.27018711e+01],
#        [2.00000000e+00, 3.00000000e+00, 3.08952310e+02],
#        [3.00000000e+00, 1.22000000e+02, 1.69069209e+01],
#        ...,
#        [5.38670000e+04, 5.26040000e+04, 5.68135563e+02],
#        [5.37730000e+04, 5.38020000e+04, 2.66336483e+02],
#        [5.38020000e+04, 5.37720000e+04, 1.29043373e+02]])

# %% [markdown]
# * Plot
